# %%
conda install -c conda-forge altair vega_datasets
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\vedav\anaconda3
#
#   added / updated specs:
#     - altair
#     - vega_datasets
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     altair-5.0.1               |     pyhd8ed1ab_1         365 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         365 KB
#
# The following packages will be UPDATED:
#
#   altair                                 4.2.0-pyhd8ed1ab_1 --> 5.0.1-pyhd8ed1ab_1 None
#
#
#
# Downloading and Extracting Packages
#
# altair-5.0.1         | 365 KB    |            |   0%
# altair-5.0.1         | 365 KB    | 4          |   4%
# altair-5.0.1         | 365 KB    | ####3      |  44%
# altair-5.0.1         | 365 KB    | #########6 |  96%
# altair-5.0.1         | 365 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Retrieving notices: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.9.0
#   latest version: 23.5.2
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda

# %%
import pandas as pd
import numpy as np 
import altair as alt 
from vega_datasets import data

# %%
df = pd.read_csv(r'C:\Users\vedav\Desktop\MS\Sem 1\Data viz\Assignment 12\JHU.csv')

# %%
df.head()
# Out:
#    OBJECTID Countyname  ST_Name ST_Abbr  ST_ID  FIPS  FatalityRa  Confirmedb  \
# 0         1    Autauga  Alabama      AL      1  1001    2.097902     1285.95
# 1         2    Baldwin  Alabama      AL      1  1003    0.820283      615.08
# 2         3    Barbour  Alabama      AL      1  1005    0.497512     1615.69
# 3         4       Bibb  Alabama      AL      1  1007    0.440529     1013.39
# 4         5     Blount  Alabama      AL      1  1009    0.302115      572.27
#
#    DeathsbyPo  PCTPOVALL_  ...  Day_7  Day_8  Day_9 Day_10 Day_11 Day_12  \
# 0   26.977932        13.8  ...   26.0    3.0   24.0   23.0    7.0    8.0
# 1    5.045362         9.8  ...   86.0   30.0   18.0   18.0   93.0   49.0
# 2    8.038262        30.9  ...    4.0    4.0    2.0    2.0   12.0   10.0
# 3    4.464286        21.8  ...    2.0    4.0    3.0    1.0   10.0    5.0
# 4    1.728907        13.2  ...    8.0    8.0    5.0    4.0    8.0    4.0
#
#   Day_13 Day_14   Shape__Area  Shape__Length
# 0   15.0    9.0  2.209382e+09  246839.865479
# 1   23.0   37.0  5.770469e+09  728445.072448
# 2    1.0    3.0  3.258643e+09  307285.154510
# 3    4.0    5.0  2.310715e+09  227886.963840
# 4   10.0    8.0  2.456058e+09  286306.840721
#
# [5 rows x 84 columns]

# %%
df = df[['Countyname','ST_Name','ST_Abbr','ST_ID','FIPS','FatalityRa','Confirmedb','Deaths','TotalPop']]

# %%
df=df.head(3250)

# %%
df.head()
# Out:
#   Countyname  ST_Name ST_Abbr  ST_ID  FIPS  FatalityRa  Confirmedb  Deaths  \
# 0    Autauga  Alabama      AL      1  1001    2.097902     1285.95      15
# 1    Baldwin  Alabama      AL      1  1003    0.820283      615.08      11
# 2    Barbour  Alabama      AL      1  1005    0.497512     1615.69       2
# 3       Bibb  Alabama      AL      1  1007    0.440529     1013.39       1
# 4     Blount  Alabama      AL      1  1009    0.302115      572.27       1
#
#    TotalPop
# 0     55200
# 1    208107
# 2     25782
# 3     22527
# 4     57645

# %%
alt.Chart(df).transform_aggregate(
    count = 'sum(Confirmedb):Q',
    groupby = ['ST_Name']
).transform_window(
    rank = 'rank(count)',
    sort = [alt.SortField('count',order = 'descending')]
).transform_filter(
    alt.datum.rank < 11
).mark_bar().encode(
    y= alt.Y('ST_Name:N', sort = '-x'),
    x= 'count:Q'
)
# Out:
# alt.Chart(...)

# %%
input_dropdown = alt.binding_select(options = ['Georgia','Texas','Mississippi','Louisiana','Virginia'])
selection = alt.selection_single(fields = ['ST_Name'], bind = input_dropdown, name = 'State')
color = alt.condition(selection,
                     alt.Color('ST_Name:N',legend = None),
                     alt.value('lightgray'))
alt.Chart(df).mark_point().encode(
    x= alt.X('Confirmedb:Q',scale = alt.Scale(domain = [0,50000])),
    y= alt.Y('Deaths:Q', scale = alt.Scale(domain = [0,4000])),
    color = color,
    tooltip = ['Countyname:N','ST_Name']
).add_selection(
    selection
).properties(
width = 800,
height =500
).interactive()
# Out:
# C:\Users\vedav\anaconda3\lib\site-packages\altair\utils\deprecation.py:65: AltairDeprecationWarning: 'selection_single' is deprecated.  Use 'selection_point'
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# C:\Users\vedav\anaconda3\lib\site-packages\altair\utils\deprecation.py:65: AltairDeprecationWarning: 'add_selection' is deprecated. Use 'add_params' instead.
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# alt.Chart(...)

# %%
counties = alt.topo_feature(data.us_10m.url, 'counties')

alt.Chart(counties).mark_geoshape().encode(
    color = alt.Color('FatalityRa:Q',scale = alt.Scale(domain = [1,10],scheme = 'bluepurple')),
    tooltip = ['FatalityRa:Q']
).transform_lookup(
    lookup='id',
    from_=alt.LookupData(df,'FIPS',['FatalityRa'])
).project(
    type='albersUsa'
).properties(
    width=500,
    height=300
)
# Out:
# alt.Chart(...)
