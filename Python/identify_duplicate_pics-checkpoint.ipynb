# %%
import hashlib
import imageio
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
# %matplotlib inline
import time
import numpy as np
import os

# %% [markdown]
# # Removing Duplicate Images Using Hashing

# %%
def file_hash(filepath):
    with open(filepath, 'rb') as f:
        return md5(f.read()).hexdigest()

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\vedav\\Documents\\remove_duplicate_image-master\\remove_duplicate_image-master'

# %%
os.chdir(r'E:/Pictures/')
os.getcwd()
# Out:
# 'E:\\Pictures'

# %%
file_list = os.listdir()
print(len(file_list))
# Out:
# 8

# %%
import hashlib, os
duplicates = []
hash_keys = dict()
for index, filename in  enumerate(os.listdir('.')):  #listdir('.') = current directory
    if os.path.isfile(filename):
        with open(filename, 'rb') as f:
            filehash = hashlib.md5(f.read()).hexdigest()
        if filehash not in hash_keys: 
            hash_keys[filehash] = index
        else:
            duplicates.append((index,hash_keys[filehash]))

# %%
data_dir= "E:/Pictures/DCIM/"

# %%
result = []
for path, subdirs, files in os.walk(data_dir):
      for name in files: 
            result.append(os.path.join(path, name))

# %%
import hashlib, os
duplicates = []
hash_keys = dict()
for index, filename in enumerate(result):  #listdir('.') = current directory
    if os.path.isfile(filename):
        with open(filename, 'rb') as f:
            filehash = hashlib.md5(f.read()).hexdigest()
        if filehash not in hash_keys: 
            hash_keys[filehash] = index
        else:
            duplicates.append((index,hash_keys[filehash]))

# %%
duplicates
# Out:
# [(1170, 1168),
#  (1172, 1168),
#  (1174, 1168),
#  (1180, 1168),
#  (1182, 1168),
#  (1185, 1168),
#  (1187, 1168),
#  (1189, 1168),
#  (1191, 1168),
#  (1195, 1193),
#  (1202, 1168),
#  (1204, 1168),
#  (2940, 2938),
#  (2942, 2938),
#  (2946, 2944),
#  (2948, 2944),
#  (2950, 2944),
#  (2952, 2944),
#  (2954, 2944),
#  (2956, 2944),
#  (2958, 2944),
#  (2960, 2944),
#  (2962, 2938),
#  (2964, 2938),
#  (2966, 2938),
#  (3164, 3162),
#  (3166, 3162),
#  (3172, 3170),
#  (3174, 3170),
#  (3176, 3170),
#  (3178, 3170),
#  (3180, 3170),
#  (3261, 3260),
#  (3409, 3407),
#  (3411, 3407),
#  (3413, 3407),
#  (3415, 3407),
#  (3417, 3407),
#  (3419, 3407),
#  (3721, 3407),
#  (3723, 3407),
#  (3727, 3725),
#  (3729, 3725),
#  (3733, 3731),
#  (3735, 3731),
#  (3737, 3731),
#  (4427, 4425),
#  (4430, 4425),
#  (4494, 4491),
#  (4497, 4491),
#  (4500, 4491),
#  (4503, 4491),
#  (4506, 4491),
#  (4509, 4491),
#  (4512, 4491),
#  (4515, 4491),
#  (4518, 4491),
#  (4530, 4527),
# ...

# %% [markdown]
# #### Identified the duplicate files in the selected folders
